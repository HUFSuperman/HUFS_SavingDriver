# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./train_label_7.csv')
df
# Out:
#        creator      date category_name  data_length    video_id  \
# 0        디투리소스  20220124         휴대폰조작            5  SGA2101512
# 1        디투리소스  20220124         휴대폰조작            5  SGA2101512
# 2        디투리소스  20220124         휴대폰조작            5  SGA2101512
# 3        디투리소스  20220124         휴대폰조작            5  SGA2101512
# 4        디투리소스  20220124         휴대폰조작            5  SGA2101512
# ...        ...       ...           ...          ...         ...
# 302210   디투리소스  20220124            통화            5  SGA2101505
# 302211   디투리소스  20220124            통화            5  SGA2101505
# 302212   디투리소스  20220124            통화            5  SGA2101505
# 302213   디투리소스  20220124            통화            5  SGA2101505
# 302214   디투리소스  20220124            통화            5  SGA2101505
#
#                scene_id                      img_id  scene_occupants  \
# 0       SGA2101512S0301  SGA2101512S0301IMG0001.jpg                1
# ...

# %%
train_df = df[df['category_name']=='운전자폭행']
train_df
# Out:
#          creator      date category_name  data_length    video_id  \
# 11505   광주인공지능센터  20220114         운전자폭행            5  SGA2101432
# 11506   광주인공지능센터  20220114         운전자폭행            5  SGA2101432
# 11507   광주인공지능센터  20220114         운전자폭행            5  SGA2101432
# 11508   광주인공지능센터  20220114         운전자폭행            5  SGA2101432
# 11509   광주인공지능센터  20220114         운전자폭행            5  SGA2101432
# ...          ...       ...           ...          ...         ...
# 265615    으뜸정보기술  20220112         운전자폭행            5  SGA2101414
# 265616    으뜸정보기술  20220112         운전자폭행            5  SGA2101414
# 265617    으뜸정보기술  20220112         운전자폭행            5  SGA2101414
# 265618    으뜸정보기술  20220112         운전자폭행            5  SGA2101414
# 265619    으뜸정보기술  20220112         운전자폭행            5  SGA2101414
#
#                scene_id                      img_id  scene_occupants  \
# 11505   SGA2101432S0197  SGA2101432S0197IMG0001.jpg                2
# ...

# %%
train_df.to_csv('./assault_label_7.csv', index=False)
